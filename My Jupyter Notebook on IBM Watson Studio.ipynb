# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Matthew Doxie**

# %% [markdown]
# _I want to become a data scientist becuase I find the analysis and interpretation of data interesting. I would really enjoy using data analysis and interpretation skills to help an organization make better decisions._

# %% [markdown]
# ### Convert kilometers to miles ###

# %%
miles = 500
kilometers = miles * 1.609344
print(kilometers)
# Out:
# 804.672

# %% [markdown]
# - 1
# - 2
# - 3
# - 4
# - 5
#
# https://ibm.com
#
# |Name|Age|Height|
# |----|---|------|
# |Matt|27|6'0|
